# %%
import findspark
findspark.init()
from pyspark import SparkContext,SparkConf
from pyspark.sql import SparkSession,SQLContext
import sys
import time
import pandas as pd

# %%
master = "local"
if len(sys.argv)==2:
    master = sys.argv[1]
spark = SparkSession.builder.appName("UDF").master(master).getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-4QACQ8P:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>UDF</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local appName=UDF>

# %%
file_path = "../data/movies.csv"

# %%
# file_data = spark.read.csv(file_path,sep=",")
file_data = spark.read.format("csv").option("header","true").load(file_path) # 使用第一行作为列名
file_data
# Out:
# DataFrame[movieId: string, title: string, genres: string]

# %% [markdown]
# #### df.head()和df.show()的区别

# %%
file_data.head(2)
# Out:
# [Row(movieId='1', title='Toy Story (1995)', genres='Adventure|Animation|Children|Comedy|Fantasy'),
#  Row(movieId='2', title='Jumanji (1995)', genres='Adventure|Children|Fantasy')]

# %%
file_data.show(2)
# Out:
# +-------+----------------+--------------------+
# |movieId|           title|              genres|
# +-------+----------------+--------------------+
# |      1|Toy Story (1995)|Adventure|Animati...|
# |      2|  Jumanji (1995)|Adventure|Childre...|
# +-------+----------------+--------------------+
# only showing top 2 rows

# %%
df_movies = file_data

# %%
# 创建视图
df_movies.createOrReplaceTempView("movies")

# %% [markdown]
# ### 使用sparksession创建出udf函数，进行查找电影类型名称的长度

# %%
from pyspark.sql.types import IntegerType
# 注册自定义函数
spark.udf.register("fun1",lambda x:len(x))
spark.sql("select genres,fun1(genres) from movies limit 5").show()
# Out:
# +--------------------+------------+
# |              genres|fun1(genres)|
# +--------------------+------------+
# |Adventure|Animati...|          43|
# |Adventure|Childre...|          26|
# |      Comedy|Romance|          14|
# |Comedy|Drama|Romance|          20|
# |              Comedy|           6|
# +--------------------+------------+

# %%
# df_movies.describe(df_movies["movieId"]) # 会出错 TypeError: Column is not iterable
df_movies.describe("movieId").show()
df_movies.describe(["movieId"]).show()
# Out:
# +-------+------------------+
# |summary|           movieId|
# +-------+------------------+
# |  count|              9125|
# |   mean|31123.291835616437|
# | stddev| 40782.63360397416|
# |    min|                 1|
# |    max|             99992|
# +-------+------------------+
#
# +-------+------------------+
# |summary|           movieId|
# +-------+------------------+
# |  count|              9125|
# |   mean|31123.291835616437|
# | stddev| 40782.63360397416|
# |    min|                 1|
# |    max|             99992|
# +-------+------------------+

# %% [markdown]
# ### RDD DataFrame DataSet

# %% [markdown]
# ## <font color="red">真就莫名其妙呗，在这里出错，结果重启一下服务再提交就可以了。。。- -</font>

# %%
# df转rdd
rdd_movies = df_movies.rdd.map(lambda x:"movieId is {},title is {},genres is {}".format(x.movieId,x.title,x.genres)).collect()

# %%
for i in rdd_movies:
    print(i)
# Out:
# movieId is 1,title is Toy Story (1995),genres is Adventure|Animation|Children|Comedy|Fantasy
# movieId is 2,title is Jumanji (1995),genres is Adventure|Children|Fantasy
# movieId is 3,title is Grumpier Old Men (1995),genres is Comedy|Romance
# movieId is 4,title is Waiting to Exhale (1995),genres is Comedy|Drama|Romance
# movieId is 5,title is Father of the Bride Part II (1995),genres is Comedy
# movieId is 6,title is Heat (1995),genres is Action|Crime|Thriller
# movieId is 7,title is Sabrina (1995),genres is Comedy|Romance
# movieId is 8,title is Tom and Huck (1995),genres is Adventure|Children
# movieId is 9,title is Sudden Death (1995),genres is Action
# movieId is 10,title is GoldenEye (1995),genres is Action|Adventure|Thriller
# movieId is 11,title is American President, The (1995),genres is Comedy|Drama|Romance
# movieId is 12,title is Dracula: Dead and Loving It (1995),genres is Comedy|Horror
# movieId is 13,title is Balto (1995),genres is Adventure|Animation|Children
# movieId is 14,title is Nixon (1995),genres is Drama
# movieId is 15,title is Cutthroat Island (1995),genres is Action|Adventure|Romance
# movieId is 16,title is Casino (1995),genres is Crime|Drama
# movieId is 17,title is Sense and Sensibility (1995),genres is Drama|Romance
# movieId is 18,title is Four Rooms (1995),genres is Comedy
# movieId is 19,title is Ace Ventura: When Nature Calls (1995),genres is Comedy
# movieId is 20,title is Money Train (1995),genres is Action|Comedy|Crime|Drama|Thriller
# movieId is 21,title is Get Shorty (1995),genres is Comedy|Crime|Thriller
# movieId is 22,title is Copycat (1995),genres is Crime|Drama|Horror|Mystery|Thriller
# movieId is 23,title is Assassins (1995),genres is Action|Crime|Thriller
# movieId is 24,title is Powder (1995),genres is Drama|Sci-Fi
# movieId is 25,title is Leaving Las Vegas (1995),genres is Drama|Romance
# movieId is 26,title is Othello (1995),genres is Drama
# movieId is 27,title is Now and Then (1995),genres is Children|Drama
# movieId is 28,title is Persuasion (1995),genres is Drama|Romance
# movieId is 29,title is City of Lost Children, The (Cité des enfants perdus, La) (1995),genres is Adventure|Drama|Fantasy|Mystery|Sci-Fi
# movieId is 30,title is Shanghai Triad (Yao a yao yao dao waipo qiao) (1995),genres is Crime|Drama
# movieId is 31,title is Dangerous Minds (1995),genres is Drama
# movieId is 32,title is Twelve Monkeys (a.k.a. 12 Monkeys) (1995),genres is Mystery|Sci-Fi|Thriller
# movieId is 34,title is Babe (1995),genres is Children|Drama
# movieId is 35,title is Carrington (1995),genres is Drama|Romance
# movieId is 36,title is Dead Man Walking (1995),genres is Crime|Drama
# movieId is 37,title is Across the Sea of Time (1995),genres is Documentary|IMAX
# movieId is 38,title is It Takes Two (1995),genres is Children|Comedy
# movieId is 39,title is Clueless (1995),genres is Comedy|Romance
# movieId is 40,title is Cry, the Beloved Country (1995),genres is Drama
# movieId is 41,title is Richard III (1995),genres is Drama|War
# movieId is 42,title is Dead Presidents (1995),genres is Action|Crime|Drama
# movieId is 43,title is Restoration (1995),genres is Drama
# movieId is 44,title is Mortal Kombat (1995),genres is Action|Adventure|Fantasy
# movieId is 45,title is To Die For (1995),genres is Comedy|Drama|Thriller
# movieId is 46,title is How to Make an American Quilt (1995),genres is Drama|Romance
# movieId is 47,title is Seven (a.k.a. Se7en) (1995),genres is Mystery|Thriller
# movieId is 48,title is Pocahontas (1995),genres is Animation|Children|Drama|Musical|Romance
# movieId is 49,title is When Night Is Falling (1995),genres is Drama|Romance
# movieId is 50,title is Usual Suspects, The (1995),genres is Crime|Mystery|Thriller
# movieId is 52,title is Mighty Aphrodite (1995),genres is Comedy|Drama|Romance
# movieId is 53,title is Lamerica (1994),genres is Adventure|Drama
# movieId is 54,title is Big Green, The (1995),genres is Children|Comedy
# movieId is 55,title is Georgia (1995),genres is Drama
# movieId is 57,title is Home for the Holidays (1995),genres is Drama
# movieId is 58,title is Postman, The (Postino, Il) (1994),genres is Comedy|Drama|Romance
# movieId is 59,title is Confessional, The (Confessionnal, Le) (1995),genres is Drama|Mystery
# movieId is 60,title is Indian in the Cupboard, The (1995),genres is Adventure|Children|Fantasy
# movieId is 61,title is Eye for an Eye (1996),genres is Drama|Thriller
# movieId is 62,title is Mr. Holland's Opus (1995),genres is Drama
# movieId is 63,title is Don't Be a Menace to South Central While Drinking Your Juice in the Hood (1996),genres is Comedy|Crime
# movieId is 64,title is Two if by Sea (1996),genres is Comedy|Romance
# movieId is 65,title is Bio-Dome (1996),genres is Comedy
# movieId is 66,title is Lawnmower Man 2: Beyond Cyberspace (1996),genres is Action|Sci-Fi|Thriller
# movieId is 68,title is French Twist (Gazon maudit) (1995),genres is Comedy|Romance
# movieId is 69,title is Friday (1995),genres is Comedy
# movieId is 70,title is From Dusk Till Dawn (1996),genres is Action|Comedy|Horror|Thriller
# movieId is 71,title is Fair Game (1995),genres is Action
# movieId is 72,title is Kicking and Screaming (1995),genres is Comedy|Drama
# movieId is 73,title is Misérables, Les (1995),genres is Drama|War
# movieId is 74,title is Bed of Roses (1996),genres is Drama|Romance
# movieId is 76,title is Screamers (1995),genres is Action|Sci-Fi|Thriller
# movieId is 77,title is Nico Icon (1995),genres is Documentary
# movieId is 78,title is Crossing Guard, The (1995),genres is Action|Crime|Drama|Thriller
# movieId is 79,title is Juror, The (1996),genres is Drama|Thriller
# movieId is 80,title is White Balloon, The (Badkonake sefid) (1995),genres is Children|Drama
# movieId is 81,title is Things to Do in Denver When You're Dead (1995),genres is Crime|Drama|Romance
# movieId is 82,title is Antonia's Line (Antonia) (1995),genres is Comedy|Drama
# movieId is 83,title is Once Upon a Time... When We Were Colored (1995),genres is Drama|Romance
# movieId is 84,title is Last Summer in the Hamptons (1995),genres is Comedy|Drama
# movieId is 85,title is Angels and Insects (1995),genres is Drama|Romance
# movieId is 86,title is White Squall (1996),genres is Action|Adventure|Drama
# movieId is 87,title is Dunston Checks In (1996),genres is Children|Comedy
# movieId is 88,title is Black Sheep (1996),genres is Comedy
# movieId is 89,title is Nick of Time (1995),genres is Action|Thriller
# movieId is 92,title is Mary Reilly (1996),genres is Drama|Horror|Thriller
# movieId is 93,title is Vampire in Brooklyn (1995),genres is Comedy|Horror|Romance
# movieId is 94,title is Beautiful Girls (1996),genres is Comedy|Drama|Romance
# movieId is 95,title is Broken Arrow (1996),genres is Action|Adventure|Thriller
# movieId is 96,title is In the Bleak Midwinter (1995),genres is Comedy|Drama
# movieId is 97,title is Hate (Haine, La) (1995),genres is Crime|Drama
# movieId is 98,title is Shopping (1994),genres is Action|Thriller
# movieId is 99,title is Heidi Fleiss: Hollywood Madam (1995),genres is Documentary
# movieId is 100,title is City Hall (1996),genres is Drama|Thriller
# movieId is 101,title is Bottle Rocket (1996),genres is Adventure|Comedy|Crime|Romance
# movieId is 102,title is Mr. Wrong (1996),genres is Comedy
# movieId is 103,title is Unforgettable (1996),genres is Mystery|Sci-Fi|Thriller
# movieId is 104,title is Happy Gilmore (1996),genres is Comedy
# movieId is 105,title is Bridges of Madison County, The (1995),genres is Drama|Romance
# movieId is 107,title is Muppet Treasure Island (1996),genres is Adventure|Children|Comedy|Musical
# movieId is 108,title is Catwalk (1996),genres is Documentary
# movieId is 110,title is Braveheart (1995),genres is Action|Drama|War
# movieId is 111,title is Taxi Driver (1976),genres is Crime|Drama|Thriller
# movieId is 112,title is Rumble in the Bronx (Hont faan kui) (1995),genres is Action|Adventure|Comedy|Crime
# movieId is 113,title is Before and After (1996),genres is Drama|Mystery
# movieId is 114,title is Margaret's Museum (1995),genres is Drama
# movieId is 116,title is Anne Frank Remembered (1995),genres is Documentary
# movieId is 117,title is Young Poisoner's Handbook, The (1995),genres is Crime|Drama
# movieId is 118,title is If Lucy Fell (1996),genres is Comedy|Romance
# movieId is 119,title is Steal Big, Steal Little (1995),genres is Comedy
# movieId is 121,title is Boys of St. Vincent, The (1992),genres is Drama
# movieId is 122,title is Boomerang (1992),genres is Comedy|Romance
# movieId is 123,title is Chungking Express (Chung Hing sam lam) (1994),genres is Drama|Mystery|Romance
# movieId is 124,title is Star Maker, The (Uomo delle stelle, L') (1995),genres is Drama
# movieId is 125,title is Flirting With Disaster (1996),genres is Comedy
# movieId is 126,title is NeverEnding Story III, The (1994),genres is Adventure|Children|Fantasy
# movieId is 129,title is Pie in the Sky (1996),genres is Comedy|Romance
# movieId is 130,title is Angela (1995),genres is Drama
# movieId is 131,title is Frankie Starlight (1995),genres is Drama|Romance
# movieId is 132,title is Jade (1995),genres is Thriller
# movieId is 135,title is Down Periscope (1996),genres is Comedy
# movieId is 137,title is Man of the Year (1995),genres is Documentary
# movieId is 140,title is Up Close and Personal (1996),genres is Drama|Romance
# movieId is 141,title is Birdcage, The (1996),genres is Comedy
# movieId is 144,title is Brothers McMullen, The (1995),genres is Comedy
# movieId is 145,title is Bad Boys (1995),genres is Action|Comedy|Crime|Drama|Thriller
# movieId is 146,title is Amazing Panda Adventure, The (1995),genres is Adventure|Children
# movieId is 147,title is Basketball Diaries, The (1995),genres is Drama
# movieId is 148,title is Awfully Big Adventure, An (1995),genres is Drama
# movieId is 149,title is Amateur (1994),genres is Crime|Drama|Thriller
# movieId is 150,title is Apollo 13 (1995),genres is Adventure|Drama|IMAX
# movieId is 151,title is Rob Roy (1995),genres is Action|Drama|Romance|War
# movieId is 152,title is Addiction, The (1995),genres is Drama|Horror
# movieId is 153,title is Batman Forever (1995),genres is Action|Adventure|Comedy|Crime
# movieId is 154,title is Beauty of the Day (Belle de jour) (1967),genres is Drama
# movieId is 155,title is Beyond Rangoon (1995),genres is Adventure|Drama|War
# movieId is 156,title is Blue in the Face (1995),genres is Comedy|Drama
# movieId is 157,title is Canadian Bacon (1995),genres is Comedy|War
# movieId is 158,title is Casper (1995),genres is Adventure|Children
# movieId is 159,title is Clockers (1995),genres is Crime|Drama|Mystery
# movieId is 160,title is Congo (1995),genres is Action|Adventure|Mystery|Sci-Fi
# movieId is 161,title is Crimson Tide (1995),genres is Drama|Thriller|War
# movieId is 162,title is Crumb (1994),genres is Documentary
# movieId is 163,title is Desperado (1995),genres is Action|Romance|Western
# movieId is 164,title is Devil in a Blue Dress (1995),genres is Crime|Film-Noir|Mystery|Thriller
# movieId is 165,title is Die Hard: With a Vengeance (1995),genres is Action|Crime|Thriller
# movieId is 166,title is Doom Generation, The (1995),genres is Comedy|Crime|Drama
# movieId is 167,title is Feast of July (1995),genres is Drama
# movieId is 168,title is First Knight (1995),genres is Action|Drama|Romance
# movieId is 169,title is Free Willy 2: The Adventure Home (1995),genres is Adventure|Children|Drama
# movieId is 170,title is Hackers (1995),genres is Action|Adventure|Crime|Thriller
# movieId is 171,title is Jeffrey (1995),genres is Comedy|Drama
# movieId is 172,title is Johnny Mnemonic (1995),genres is Action|Sci-Fi|Thriller
# movieId is 173,title is Judge Dredd (1995),genres is Action|Crime|Sci-Fi
# movieId is 174,title is Jury Duty (1995),genres is Comedy
# movieId is 175,title is Kids (1995),genres is Drama
# movieId is 176,title is Living in Oblivion (1995),genres is Comedy
# movieId is 177,title is Lord of Illusions (1995),genres is Horror
# movieId is 178,title is Love & Human Remains (1993),genres is Comedy|Drama
# movieId is 179,title is Mad Love (1995),genres is Drama|Romance
# movieId is 180,title is Mallrats (1995),genres is Comedy|Romance
# movieId is 181,title is Mighty Morphin Power Rangers: The Movie (1995),genres is Action|Children
# movieId is 183,title is Mute Witness (1994),genres is Comedy|Horror|Thriller
# movieId is 184,title is Nadja (1994),genres is Drama
# movieId is 185,title is Net, The (1995),genres is Action|Crime|Thriller
# movieId is 186,title is Nine Months (1995),genres is Comedy|Romance
# movieId is 187,title is Party Girl (1995),genres is Comedy
# movieId is 188,title is Prophecy, The (1995),genres is Fantasy|Horror|Mystery
# movieId is 189,title is Reckless (1995),genres is Comedy|Fantasy
# movieId is 190,title is Safe (1995),genres is Thriller
# movieId is 191,title is Scarlet Letter, The (1995),genres is Drama|Romance
# movieId is 193,title is Showgirls (1995),genres is Drama
# movieId is 194,title is Smoke (1995),genres is Comedy|Drama
# movieId is 195,title is Something to Talk About (1995),genres is Comedy|Drama|Romance
# movieId is 196,title is Species (1995),genres is Horror|Sci-Fi
# movieId is 198,title is Strange Days (1995),genres is Action|Crime|Drama|Mystery|Sci-Fi|Thriller
# movieId is 199,title is Umbrellas of Cherbourg, The (Parapluies de Cherbourg, Les) (1964),genres is Drama|Musical|Romance
# movieId is 200,title is Tie That Binds, The (1995),genres is Thriller
# movieId is 201,title is Three Wishes (1995),genres is Drama|Fantasy
# movieId is 202,title is Total Eclipse (1995),genres is Drama|Romance
# movieId is 203,title is To Wong Foo, Thanks for Everything! Julie Newmar (1995),genres is Comedy
# movieId is 204,title is Under Siege 2: Dark Territory (1995),genres is Action
# movieId is 205,title is Unstrung Heroes (1995),genres is Comedy|Drama
# movieId is 206,title is Unzipped (1995),genres is Documentary
# movieId is 207,title is Walk in the Clouds, A (1995),genres is Drama|Romance
# movieId is 208,title is Waterworld (1995),genres is Action|Adventure|Sci-Fi
# movieId is 209,title is White Man's Burden (1995),genres is Drama
# movieId is 211,title is Browning Version, The (1994),genres is Drama
# movieId is 213,title is Burnt by the Sun (Utomlyonnye solntsem) (1994),genres is Drama
# movieId is 214,title is Before the Rain (Pred dozhdot) (1994),genres is Drama|War
# movieId is 215,title is Before Sunrise (1995),genres is Drama|Romance
# movieId is 216,title is Billy Madison (1995),genres is Comedy
# movieId is 217,title is Babysitter, The (1995),genres is Drama|Thriller
# movieId is 218,title is Boys on the Side (1995),genres is Comedy|Drama
# movieId is 219,title is Cure, The (1995),genres is Drama
# movieId is 220,title is Castle Freak (1995),genres is Horror
# movieId is 222,title is Circle of Friends (1995),genres is Drama|Romance
# movieId is 223,title is Clerks (1994),genres is Comedy
# movieId is 224,title is Don Juan DeMarco (1995),genres is Comedy|Drama|Romance
# movieId is 225,title is Disclosure (1994),genres is Drama|Thriller
# movieId is 227,title is Drop Zone (1994),genres is Action|Thriller
# movieId is 228,title is Destiny Turns on the Radio (1995),genres is Comedy
# movieId is 229,title is Death and the Maiden (1994),genres is Drama|Thriller
# movieId is 230,title is Dolores Claiborne (1995),genres is Drama|Thriller
# movieId is 231,title is Dumb & Dumber (Dumb and Dumber) (1994),genres is Adventure|Comedy
# movieId is 232,title is Eat Drink Man Woman (Yin shi nan nu) (1994),genres is Comedy|Drama|Romance
# movieId is 233,title is Exotica (1994),genres is Drama
# movieId is 234,title is Exit to Eden (1994),genres is Comedy
# movieId is 235,title is Ed Wood (1994),genres is Comedy|Drama
# movieId is 236,title is French Kiss (1995),genres is Action|Comedy|Romance
# movieId is 237,title is Forget Paris (1995),genres is Comedy|Romance
# movieId is 238,title is Far From Home: The Adventures of Yellow Dog (1995),genres is Adventure|Children
# movieId is 239,title is Goofy Movie, A (1995),genres is Animation|Children|Comedy|Romance
# movieId is 240,title is Hideaway (1995),genres is Thriller
# movieId is 241,title is Fluke (1995),genres is Children|Drama
# movieId is 242,title is Farinelli: il castrato (1994),genres is Drama|Musical
# movieId is 243,title is Gordy (1995),genres is Children|Comedy|Fantasy
# movieId is 244,title is Gumby: The Movie (1995),genres is Animation|Children
# movieId is 245,title is The Glass Shield (1994),genres is Crime|Drama
# movieId is 246,title is Hoop Dreams (1994),genres is Documentary
# movieId is 247,title is Heavenly Creatures (1994),genres is Crime|Drama
# movieId is 248,title is Houseguest (1994),genres is Comedy
# movieId is 249,title is Immortal Beloved (1994),genres is Drama|Romance
# movieId is 250,title is Heavyweights (Heavy Weights) (1995),genres is Children|Comedy
# movieId is 251,title is Hunted, The (1995),genres is Action
# movieId is 252,title is I.Q. (1994),genres is Comedy|Romance
# movieId is 253,title is Interview with the Vampire: The Vampire Chronicles (1994),genres is Drama|Horror
# movieId is 254,title is Jefferson in Paris (1995),genres is Drama
# movieId is 255,title is Jerky Boys, The (1995),genres is Comedy
# movieId is 256,title is Junior (1994),genres is Comedy|Sci-Fi
# movieId is 257,title is Just Cause (1995),genres is Mystery|Thriller
# movieId is 258,title is Kid in King Arthur's Court, A (1995),genres is Adventure|Children|Comedy|Fantasy|Romance
# movieId is 259,title is Kiss of Death (1995),genres is Crime|Drama|Thriller
# movieId is 260,title is Star Wars: Episode IV - A New Hope (1977),genres is Action|Adventure|Sci-Fi
# movieId is 261,title is Little Women (1994),genres is Drama
# movieId is 262,title is Little Princess, A (1995),genres is Children|Drama
# movieId is 263,title is Ladybird Ladybird (1994),genres is Drama
# movieId is 264,title is Enfer, L' (1994),genres is Drama
# movieId is 265,title is Like Water for Chocolate (Como agua para chocolate) (1992),genres is Drama|Fantasy|Romance
# movieId is 266,title is Legends of the Fall (1994),genres is Drama|Romance|War|Western
# movieId is 267,title is Major Payne (1995),genres is Comedy
# movieId is 268,title is Little Odessa (1994),genres is Crime|Drama
# movieId is 269,title is My Crazy Life (Mi vida loca) (1993),genres is Drama
# movieId is 270,title is Love Affair (1994),genres is Drama|Romance
# movieId is 271,title is Losing Isaiah (1995),genres is Drama
# movieId is 272,title is Madness of King George, The (1994),genres is Comedy|Drama
# movieId is 273,title is Mary Shelley's Frankenstein (Frankenstein) (1994),genres is Drama|Horror|Sci-Fi
# movieId is 274,title is Man of the House (1995),genres is Comedy
# movieId is 275,title is Mixed Nuts (1994),genres is Comedy
# movieId is 276,title is Milk Money (1994),genres is Comedy|Romance
# movieId is 277,title is Miracle on 34th Street (1994),genres is Drama
# movieId is 278,title is Miami Rhapsody (1995),genres is Comedy
# movieId is 279,title is My Family (1995),genres is Drama
# movieId is 280,title is Murder in the First (1995),genres is Drama|Thriller
# movieId is 281,title is Nobody's Fool (1994),genres is Comedy|Drama|Romance
# movieId is 282,title is Nell (1994),genres is Drama
# movieId is 283,title is New Jersey Drive (1995),genres is Crime|Drama
# movieId is 285,title is Beyond Bedlam (1993),genres is Drama|Horror
# movieId is 287,title is Nina Takes a Lover (1994),genres is Comedy|Romance
# movieId is 288,title is Natural Born Killers (1994),genres is Action|Crime|Thriller
# movieId is 289,title is Only You (1994),genres is Comedy|Romance
# movieId is 290,title is Once Were Warriors (1994),genres is Crime|Drama
# movieId is 291,title is Poison Ivy II (1996),genres is Drama|Thriller
# movieId is 292,title is Outbreak (1995),genres is Action|Drama|Sci-Fi|Thriller
# movieId is 293,title is Léon: The Professional (a.k.a. The Professional) (Léon) (1994),genres is Action|Crime|Drama|Thriller
# movieId is 294,title is Perez Family, The (1995),genres is Comedy|Romance
# movieId is 295,title is Pyromaniac's Love Story, A (1995),genres is Comedy|Romance
# movieId is 296,title is Pulp Fiction (1994),genres is Comedy|Crime|Drama|Thriller
# movieId is 299,title is Priest (1994),genres is Drama
# movieId is 300,title is Quiz Show (1994),genres is Drama
# movieId is 301,title is Picture Bride (Bijo photo) (1994),genres is Drama|Romance
# movieId is 302,title is Queen Margot (Reine Margot, La) (1994),genres is Drama|Romance
# movieId is 303,title is Quick and the Dead, The (1995),genres is Action|Thriller|Western
# movieId is 304,title is Roommates (1995),genres is Comedy|Drama
# movieId is 305,title is Ready to Wear (Pret-A-Porter) (1994),genres is Comedy
# movieId is 306,title is Three Colors: Red (Trois couleurs: Rouge) (1994),genres is Drama
# movieId is 307,title is Three Colors: Blue (Trois couleurs: Bleu) (1993),genres is Drama
# movieId is 308,title is Three Colors: White (Trzy kolory: Bialy) (1994),genres is Comedy|Drama
# movieId is 309,title is Red Firecracker, Green Firecracker (Pao Da Shuang Deng) (1994),genres is Drama
# movieId is 312,title is Stuart Saves His Family (1995),genres is Comedy
# movieId is 313,title is Swan Princess, The (1994),genres is Animation|Children
# movieId is 314,title is Secret of Roan Inish, The (1994),genres is Children|Drama|Fantasy|Mystery
# movieId is 315,title is Specialist, The (1994),genres is Action|Drama|Thriller
# movieId is 316,title is Stargate (1994),genres is Action|Adventure|Sci-Fi
# movieId is 317,title is Santa Clause, The (1994),genres is Comedy|Drama|Fantasy
# movieId is 318,title is Shawshank Redemption, The (1994),genres is Crime|Drama
# movieId is 319,title is Shallow Grave (1994),genres is Comedy|Drama|Thriller
# movieId is 320,title is Suture (1993),genres is Film-Noir|Thriller
# movieId is 321,title is Strawberry and Chocolate (Fresa y chocolate) (1993),genres is Drama
# movieId is 322,title is Swimming with Sharks (1995),genres is Comedy|Drama
# movieId is 324,title is Sum of Us, The (1994),genres is Comedy|Drama
# movieId is 325,title is National Lampoon's Senior Trip (1995),genres is Comedy
# movieId is 326,title is To Live (Huozhe) (1994),genres is Drama
# movieId is 327,title is Tank Girl (1995),genres is Action|Comedy|Sci-Fi
# movieId is 328,title is Tales from the Crypt Presents: Demon Knight (1995),genres is Horror|Thriller
# movieId is 329,title is Star Trek: Generations (1994),genres is Adventure|Drama|Sci-Fi
# movieId is 330,title is Tales from the Hood (1995),genres is Action|Crime|Horror
# movieId is 331,title is Tom & Viv (1994),genres is Drama
# movieId is 332,title is Village of the Damned (1995),genres is Horror|Sci-Fi
# movieId is 333,title is Tommy Boy (1995),genres is Comedy
# movieId is 334,title is Vanya on 42nd Street (1994),genres is Drama
# movieId is 335,title is Underneath (1995),genres is Mystery|Thriller
# movieId is 336,title is Walking Dead, The (1995),genres is Drama|War
# movieId is 337,title is What's Eating Gilbert Grape (1993),genres is Drama
# movieId is 338,title is Virtuosity (1995),genres is Action|Sci-Fi|Thriller
# movieId is 339,title is While You Were Sleeping (1995),genres is Comedy|Romance
# movieId is 340,title is War, The (1994),genres is Adventure|Drama|War
# movieId is 341,title is Double Happiness (1994),genres is Drama
# movieId is 342,title is Muriel's Wedding (1994),genres is Comedy
# movieId is 343,title is Baby-Sitters Club, The (1995),genres is Children
# movieId is 344,title is Ace Ventura: Pet Detective (1994),genres is Comedy
# movieId is 345,title is Adventures of Priscilla, Queen of the Desert, The (1994),genres is Comedy|Drama
# movieId is 346,title is Backbeat (1993),genres is Drama|Musical
# movieId is 347,title is Bitter Moon (1992),genres is Drama|Film-Noir|Romance
# movieId is 348,title is Bullets Over Broadway (1994),genres is Comedy
# movieId is 349,title is Clear and Present Danger (1994),genres is Action|Crime|Drama|Thriller
# movieId is 350,title is Client, The (1994),genres is Drama|Mystery|Thriller
# movieId is 351,title is Corrina, Corrina (1994),genres is Comedy|Drama|Romance
# movieId is 352,title is Crooklyn (1994),genres is Comedy|Drama
# movieId is 353,title is Crow, The (1994),genres is Action|Crime|Fantasy|Thriller
# movieId is 354,title is Cobb (1994),genres is Drama
# movieId is 355,title is Flintstones, The (1994),genres is Children|Comedy|Fantasy
# movieId is 356,title is Forrest Gump (1994),genres is Comedy|Drama|Romance|War
# movieId is 357,title is Four Weddings and a Funeral (1994),genres is Comedy|Romance
# movieId is 358,title is Higher Learning (1995),genres is Drama
# movieId is 360,title is I Love Trouble (1994),genres is Action|Comedy
# movieId is 361,title is It Could Happen to You (1994),genres is Comedy|Drama|Romance
# movieId is 362,title is Jungle Book, The (1994),genres is Adventure|Children|Romance
# movieId is 363,title is Wonderful, Horrible Life of Leni Riefenstahl, The (Macht der Bilder: Leni Riefenstahl, Die) (1993),genres is Documentary
# movieId is 364,title is Lion King, The (1994),genres is Adventure|Animation|Children|Drama|Musical|IMAX
# movieId is 365,title is Little Buddha (1993),genres is Drama
# movieId is 366,title is Wes Craven's New Nightmare (Nightmare on Elm Street Part 7: Freddy's Finale, A) (1994),genres is Drama|Horror|Mystery|Thriller
# movieId is 367,title is Mask, The (1994),genres is Action|Comedy|Crime|Fantasy
# movieId is 368,title is Maverick (1994),genres is Adventure|Comedy|Western
# movieId is 369,title is Mrs. Parker and the Vicious Circle (1994),genres is Drama
# movieId is 370,title is Naked Gun 33 1/3: The Final Insult (1994),genres is Action|Comedy
# movieId is 371,title is Paper, The (1994),genres is Comedy|Drama
# movieId is 372,title is Reality Bites (1994),genres is Comedy|Drama|Romance
# movieId is 373,title is Red Rock West (1992),genres is Thriller
# movieId is 374,title is Richie Rich (1994),genres is Children|Comedy
# movieId is 375,title is Safe Passage (1994),genres is Drama
# movieId is 376,title is River Wild, The (1994),genres is Action|Thriller
# movieId is 377,title is Speed (1994),genres is Action|Romance|Thriller
# movieId is 378,title is Speechless (1994),genres is Comedy|Romance
# movieId is 379,title is Timecop (1994),genres is Action|Sci-Fi|Thriller
# movieId is 380,title is True Lies (1994),genres is Action|Adventure|Comedy|Romance|Thriller
# movieId is 381,title is When a Man Loves a Woman (1994),genres is Drama|Romance
# movieId is 382,title is Wolf (1994),genres is Drama|Horror|Romance|Thriller
# movieId is 383,title is Wyatt Earp (1994),genres is Western
# movieId is 384,title is Bad Company (1995),genres is Action|Crime|Drama
# movieId is 387,title is Low Down Dirty Shame, A (1994),genres is Action|Comedy
# movieId is 388,title is Boys Life (1995),genres is Drama
# movieId is 389,title is Colonel Chabert, Le (1994),genres is Drama|Romance|War
# movieId is 390,title is Faster Pussycat! Kill! Kill! (1965),genres is Action|Crime|Drama
# movieId is 391,title is Jason's Lyric (1994),genres is Crime|Drama
# movieId is 392,title is Secret Adventures of Tom Thumb, The (1993),genres is Adventure|Animation
# movieId is 393,title is Street Fighter (1994),genres is Action|Adventure|Fantasy
# movieId is 401,title is Mirage (1995),genres is Action|Thriller
# movieId is 405,title is Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994),genres is Action|Fantasy
# movieId is 407,title is In the Mouth of Madness (1995),genres is Horror|Thriller
# movieId is 408,title is 8 Seconds (1994),genres is Drama
# movieId is 409,title is Above the Rim (1994),genres is Crime|Drama
# movieId is 410,title is Addams Family Values (1993),genres is Children|Comedy|Fantasy
# movieId is 412,title is Age of Innocence, The (1993),genres is Drama
# movieId is 413,title is Airheads (1994),genres is Comedy
# movieId is 414,title is Air Up There, The (1994),genres is Comedy
# movieId is 415,title is Another Stakeout (1993),genres is Comedy|Thriller
# movieId is 416,title is Bad Girls (1994),genres is Western
# movieId is 417,title is Barcelona (1994),genres is Comedy|Romance
# movieId is 418,title is Being Human (1993),genres is Drama
# movieId is 419,title is Beverly Hillbillies, The (1993),genres is Comedy
# movieId is 420,title is Beverly Hills Cop III (1994),genres is Action|Comedy|Crime|Thriller
# movieId is 421,title is Black Beauty (1994),genres is Adventure|Children|Drama
# movieId is 422,title is Blink (1994),genres is Thriller
# movieId is 423,title is Blown Away (1994),genres is Action|Thriller
# movieId is 424,title is Blue Chips (1994),genres is Drama
# movieId is 425,title is Blue Sky (1994),genres is Drama|Romance
# movieId is 426,title is Body Snatchers (1993),genres is Horror|Sci-Fi|Thriller
# movieId is 427,title is Boxing Helena (1993),genres is Drama|Mystery|Romance|Thriller
# movieId is 428,title is Bronx Tale, A (1993),genres is Drama
# movieId is 429,title is Cabin Boy (1994),genres is Comedy
# movieId is 431,title is Carlito's Way (1993),genres is Crime|Drama
# movieId is 432,title is City Slickers II: The Legend of Curly's Gold (1994),genres is Adventure|Comedy|Western
# movieId is 433,title is Clean Slate (1994),genres is Comedy
# movieId is 434,title is Cliffhanger (1993),genres is Action|Adventure|Thriller
# movieId is 435,title is Coneheads (1993),genres is Comedy|Sci-Fi
# movieId is 436,title is Color of Night (1994),genres is Drama|Thriller
# movieId is 437,title is Cops and Robbersons (1994),genres is Comedy
# movieId is 438,title is Cowboy Way, The (1994),genres is Action|Comedy|Drama
# movieId is 439,title is Dangerous Game (1993),genres is Drama
# movieId is 440,title is Dave (1993),genres is Comedy|Romance
# movieId is 441,title is Dazed and Confused (1993),genres is Comedy
# movieId is 442,title is Demolition Man (1993),genres is Action|Adventure|Sci-Fi
# movieId is 443,title is Endless Summer 2, The (1994),genres is Adventure|Documentary
# movieId is 444,title is Even Cowgirls Get the Blues (1993),genres is Comedy|Romance
# movieId is 445,title is Fatal Instinct (1993),genres is Comedy
# movieId is 446,title is Farewell My Concubine (Ba wang bie ji) (1993),genres is Drama|Romance
# movieId is 447,title is Favor, The (1994),genres is Comedy|Romance
# movieId is 448,title is Fearless (1993),genres is Drama
# movieId is 449,title is Fear of a Black Hat (1994),genres is Comedy
# movieId is 450,title is With Honors (1994),genres is Comedy|Drama
# movieId is 451,title is Flesh and Bone (1993),genres is Drama|Mystery|Romance
# movieId is 452,title is Widows' Peak (1994),genres is Drama
# movieId is 453,title is For Love or Money (1993),genres is Comedy|Romance
# movieId is 454,title is Firm, The (1993),genres is Drama|Thriller
# movieId is 455,title is Free Willy (1993),genres is Adventure|Children|Drama
# movieId is 456,title is Fresh (1994),genres is Crime|Drama|Thriller
# movieId is 457,title is Fugitive, The (1993),genres is Thriller
# movieId is 458,title is Geronimo: An American Legend (1993),genres is Drama|Western
# movieId is 459,title is Getaway, The (1994),genres is Action|Adventure|Crime|Drama|Romance|Thriller
# movieId is 460,title is Getting Even with Dad (1994),genres is Comedy
# movieId is 461,title is Go Fish (1994),genres is Drama|Romance
# movieId is 463,title is Guilty as Sin (1993),genres is Crime|Drama|Thriller
# movieId is 464,title is Hard Target (1993),genres is Action|Adventure|Crime|Thriller
# movieId is 465,title is Heaven & Earth (1993),genres is Action|Drama|War
# movieId is 466,title is Hot Shots! Part Deux (1993),genres is Action|Comedy|War
# movieId is 467,title is Live Nude Girls (1995),genres is Comedy
# movieId is 468,title is Englishman Who Went Up a Hill But Came Down a Mountain, The (1995),genres is Comedy|Romance
# movieId is 469,title is House of the Spirits, The (1993),genres is Drama|Romance
# movieId is 470,title is House Party 3 (1994),genres is Comedy
# movieId is 471,title is Hudsucker Proxy, The (1994),genres is Comedy
# movieId is 472,title is I'll Do Anything (1994),genres is Comedy|Drama
# movieId is 473,title is In the Army Now (1994),genres is Comedy|War
# movieId is 474,title is In the Line of Fire (1993),genres is Action|Thriller
# movieId is 475,title is In the Name of the Father (1993),genres is Drama
# movieId is 476,title is Inkwell, The (1994),genres is Comedy|Drama
# movieId is 477,title is What's Love Got to Do with It? (1993),genres is Drama|Musical
# movieId is 479,title is Judgment Night (1993),genres is Action|Crime|Thriller
# movieId is 480,title is Jurassic Park (1993),genres is Action|Adventure|Sci-Fi|Thriller
# movieId is 481,title is Kalifornia (1993),genres is Drama|Thriller
# movieId is 482,title is Killing Zoe (1994),genres is Crime|Drama|Thriller
# movieId is 483,title is King of the Hill (1993),genres is Drama
# movieId is 484,title is Lassie (1994),genres is Adventure|Children
# movieId is 485,title is Last Action Hero (1993),genres is Action|Adventure|Comedy|Fantasy
# movieId is 486,title is Life with Mikey (1993),genres is Comedy
# movieId is 487,title is Lightning Jack (1994),genres is Comedy|Western
# movieId is 488,title is M. Butterfly (1993),genres is Drama|Romance
# movieId is 489,title is Made in America (1993),genres is Comedy
# movieId is 490,title is Malice (1993),genres is Thriller
# movieId is 491,title is Man Without a Face, The (1993),genres is Drama
# movieId is 492,title is Manhattan Murder Mystery (1993),genres is Comedy|Mystery
# movieId is 493,title is Menace II Society (1993),genres is Action|Crime|Drama
# movieId is 494,title is Executive Decision (1996),genres is Action|Adventure|Thriller
# movieId is 495,title is In the Realm of the Senses (Ai no corrida) (1976),genres is Drama
# movieId is 496,title is What Happened Was... (1994),genres is Comedy|Drama|Romance|Thriller
# movieId is 497,title is Much Ado About Nothing (1993),genres is Comedy|Romance
# movieId is 498,title is Mr. Jones (1993),genres is Drama|Romance
# movieId is 499,title is Mr. Wonderful (1993),genres is Comedy|Romance
# movieId is 500,title is Mrs. Doubtfire (1993),genres is Comedy|Drama
# movieId is 501,title is Naked (1993),genres is Drama
# movieId is 502,title is Next Karate Kid, The (1994),genres is Action|Children|Romance
# movieId is 504,title is No Escape (1994),genres is Action|Drama|Sci-Fi
# movieId is 505,title is North (1994),genres is Comedy
# movieId is 506,title is Orlando (1992),genres is Drama|Fantasy|Romance
# movieId is 507,title is Perfect World, A (1993),genres is Crime|Drama|Thriller
# movieId is 508,title is Philadelphia (1993),genres is Drama
# movieId is 509,title is Piano, The (1993),genres is Drama|Romance
# movieId is 510,title is Poetic Justice (1993),genres is Drama
# movieId is 511,title is Program, The (1993),genres is Action|Drama
# movieId is 512,title is Puppet Masters, The (1994),genres is Horror|Sci-Fi
# movieId is 513,title is Radioland Murders (1994),genres is Comedy|Mystery|Romance
# movieId is 514,title is Ref, The (1994),genres is Comedy
# movieId is 515,title is Remains of the Day, The (1993),genres is Drama|Romance
# movieId is 516,title is Renaissance Man (1994),genres is Comedy|Drama
# movieId is 517,title is Rising Sun (1993),genres is Action|Drama|Mystery
# movieId is 518,title is Road to Wellville, The (1994),genres is Comedy
# movieId is 519,title is RoboCop 3 (1993),genres is Action|Crime|Drama|Sci-Fi|Thriller
# movieId is 520,title is Robin Hood: Men in Tights (1993),genres is Comedy
# movieId is 521,title is Romeo Is Bleeding (1993),genres is Crime|Thriller
# movieId is 522,title is Romper Stomper (1992),genres is Action|Drama
# movieId is 523,title is Ruby in Paradise (1993),genres is Drama
# movieId is 524,title is Rudy (1993),genres is Drama
# movieId is 526,title is Savage Nights (Nuits fauves, Les) (1992),genres is Drama
# movieId is 527,title is Schindler's List (1993),genres is Drama|War
# movieId is 528,title is Scout, The (1994),genres is Comedy|Drama
# movieId is 529,title is Searching for Bobby Fischer (1993),genres is Drama
# movieId is 531,title is Secret Garden, The (1993),genres is Children|Drama
# movieId is 532,title is Serial Mom (1994),genres is Comedy|Crime|Horror
# movieId is 533,title is Shadow, The (1994),genres is Action|Adventure|Fantasy|Mystery
# movieId is 534,title is Shadowlands (1993),genres is Drama|Romance
# movieId is 535,title is Short Cuts (1993),genres is Drama
# movieId is 536,title is Simple Twist of Fate, A (1994),genres is Drama
# movieId is 537,title is Sirens (1994),genres is Drama
# movieId is 538,title is Six Degrees of Separation (1993),genres is Drama
# movieId is 539,title is Sleepless in Seattle (1993),genres is Comedy|Drama|Romance
# movieId is 540,title is Sliver (1993),genres is Thriller
# movieId is 541,title is Blade Runner (1982),genres is Action|Sci-Fi|Thriller
# movieId is 542,title is Son in Law (1993),genres is Comedy|Drama|Romance
# movieId is 543,title is So I Married an Axe Murderer (1993),genres is Comedy|Romance|Thriller
# movieId is 544,title is Striking Distance (1993),genres is Action|Crime
# movieId is 546,title is Super Mario Bros. (1993),genres is Action|Adventure|Children|Comedy|Fantasy|Sci-Fi
# movieId is 547,title is Surviving the Game (1994),genres is Action|Adventure|Thriller
# movieId is 548,title is Terminal Velocity (1994),genres is Action|Mystery|Thriller
# movieId is 549,title is Thirty-Two Short Films About Glenn Gould (1993),genres is Drama|Musical
# movieId is 550,title is Threesome (1994),genres is Comedy|Romance
# movieId is 551,title is Nightmare Before Christmas, The (1993),genres is Animation|Children|Fantasy|Musical
# movieId is 552,title is Three Musketeers, The (1993),genres is Action|Adventure|Comedy|Romance
# movieId is 553,title is Tombstone (1993),genres is Action|Drama|Western
# movieId is 554,title is Trial by Jury (1994),genres is Crime|Drama|Thriller
# movieId is 555,title is True Romance (1993),genres is Crime|Thriller
# movieId is 556,title is War Room, The (1993),genres is Documentary
# movieId is 558,title is Pagemaster, The (1994),genres is Action|Adventure|Animation|Children|Fantasy
# movieId is 559,title is Paris, France (1993),genres is Comedy
# movieId is 561,title is Killer (Bulletproof Heart) (1994),genres is Drama|Thriller
# movieId is 562,title is Welcome to the Dollhouse (1995),genres is Comedy|Drama
# movieId is 563,title is Germinal (1993),genres is Drama|Romance
# movieId is 564,title is Chasers (1994),genres is Comedy
# movieId is 565,title is Cronos (1993),genres is Drama|Horror
# movieId is 567,title is Kika (1993),genres is Comedy|Drama
# movieId is 568,title is Bhaji on the Beach (1993),genres is Comedy|Drama
# movieId is 569,title is Little Big League (1994),genres is Comedy|Drama
# movieId is 571,title is Wedding Gift, The (1994),genres is Drama|Romance
# movieId is 573,title is Ciao, Professore! (Io speriamo che me la cavo) (1992),genres is Drama
# movieId is 574,title is Spanking the Monkey (1994),genres is Comedy|Drama
# movieId is 575,title is Little Rascals, The (1994),genres is Children|Comedy
# movieId is 577,title is Andre (1994),genres is Adventure|Children|Drama
# movieId is 580,title is Princess Caraboo (1994),genres is Drama
# movieId is 581,title is Celluloid Closet, The (1995),genres is Documentary
# movieId is 582,title is Métisse (Café au Lait) (1993),genres is Comedy|Drama
# movieId is 585,title is Brady Bunch Movie, The (1995),genres is Comedy
# movieId is 586,title is Home Alone (1990),genres is Children|Comedy
# movieId is 587,title is Ghost (1990),genres is Comedy|Drama|Fantasy|Romance|Thriller
# movieId is 588,title is Aladdin (1992),genres is Adventure|Animation|Children|Comedy|Musical
# movieId is 589,title is Terminator 2: Judgment Day (1991),genres is Action|Sci-Fi
# movieId is 590,title is Dances with Wolves (1990),genres is Adventure|Drama|Western
# movieId is 592,title is Batman (1989),genres is Action|Crime|Thriller
# movieId is 593,title is Silence of the Lambs, The (1991),genres is Crime|Horror|Thriller
# movieId is 594,title is Snow White and the Seven Dwarfs (1937),genres is Animation|Children|Drama|Fantasy|Musical
# movieId is 595,title is Beauty and the Beast (1991),genres is Animation|Children|Fantasy|Musical|Romance|IMAX
# movieId is 596,title is Pinocchio (1940),genres is Animation|Children|Fantasy|Musical
# movieId is 597,title is Pretty Woman (1990),genres is Comedy|Romance
# movieId is 599,title is Wild Bunch, The (1969),genres is Adventure|Western
# movieId is 600,title is Love and a .45 (1994),genres is Action|Comedy|Crime
# movieId is 603,title is Bye Bye, Love (1995),genres is Comedy
# movieId is 605,title is One Fine Day (1996),genres is Drama|Romance
# movieId is 606,title is Candyman: Farewell to the Flesh (1995),genres is Fantasy|Horror
# movieId is 608,title is Fargo (1996),genres is Comedy|Crime|Drama|Thriller
# movieId is 609,title is Homeward Bound II: Lost in San Francisco (1996),genres is Adventure|Children
# movieId is 610,title is Heavy Metal (1981),genres is Action|Adventure|Animation|Horror|Sci-Fi
# movieId is 611,title is Hellraiser: Bloodline (1996),genres is Action|Horror|Sci-Fi
# movieId is 612,title is Pallbearer, The (1996),genres is Comedy
# movieId is 613,title is Jane Eyre (1996),genres is Drama|Romance
# movieId is 614,title is Loaded (1994),genres is Drama|Thriller
# movieId is 615,title is Bread and Chocolate (Pane e cioccolata) (1973),genres is Comedy|Drama
# movieId is 616,title is Aristocats, The (1970),genres is Animation|Children
# movieId is 617,title is Flower of My Secret, The (La flor de mi secreto) (1995),genres is Comedy|Drama
# movieId is 619,title is Ed (1996),genres is Comedy
# movieId is 620,title is Scream of Stone (Cerro Torre: Schrei aus Stein) (1991),genres is Drama
# movieId is 621,title is My Favorite Season (1993),genres is Drama
# movieId is 626,title is Thin Line Between Love and Hate, A (1996),genres is Comedy
# movieId is 627,title is Last Supper, The (1995),genres is Drama|Thriller
# movieId is 628,title is Primal Fear (1996),genres is Crime|Drama|Mystery|Thriller
# movieId is 630,title is Carried Away (1996),genres is Drama|Romance
# movieId is 631,title is All Dogs Go to Heaven 2 (1996),genres is Adventure|Animation|Children|Fantasy|Musical|Romance
# movieId is 632,title is Land and Freedom (Tierra y libertad) (1995),genres is Drama|War
# movieId is 633,title is Denise Calls Up (1995),genres is Comedy
# movieId is 635,title is Family Thing, A (1996),genres is Comedy|Drama
# movieId is 637,title is Sgt. Bilko (1996),genres is Comedy
# movieId is 638,title is Jack and Sarah (1995),genres is Romance
# movieId is 639,title is Girl 6 (1996),genres is Comedy|Drama
# movieId is 640,title is Diabolique (1996),genres is Drama|Thriller
# movieId is 647,title is Courage Under Fire (1996),genres is Action|Crime|Drama|War
# movieId is 648,title is Mission: Impossible (1996),genres is Action|Adventure|Mystery|Thriller
# movieId is 650,title is Moll Flanders (1996),genres is Drama
# movieId is 651,title is Superweib, Das (1996),genres is Comedy
# movieId is 653,title is Dragonheart (1996),genres is Action|Adventure|Fantasy
# movieId is 656,title is Eddie (1996),genres is Comedy
# movieId is 659,title is Purple Noon (Plein soleil) (1960),genres is Crime|Drama|Thriller
# movieId is 661,title is James and the Giant Peach (1996),genres is Adventure|Animation|Children|Fantasy|Musical
# movieId is 662,title is Fear (1996),genres is Thriller
# movieId is 663,title is Kids in the Hall: Brain Candy (1996),genres is Comedy
# movieId is 664,title is Faithful (1996),genres is Comedy
# movieId is 665,title is Underground (1995),genres is Comedy|Drama|War
# movieId is 667,title is Bloodsport 2 (a.k.a. Bloodsport II: The Next Kumite) (1996),genres is Action
# movieId is 668,title is Song of the Little Road (Pather Panchali) (1955),genres is Drama
# movieId is 670,title is World of Apu, The (Apur Sansar) (1959),genres is Drama
# movieId is 671,title is Mystery Science Theater 3000: The Movie (1996),genres is Comedy|Sci-Fi
# movieId is 673,title is Space Jam (1996),genres is Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi
# movieId is 674,title is Barbarella (1968),genres is Adventure|Comedy|Sci-Fi
# movieId is 678,title is Some Folks Call It a Sling Blade (1993),genres is Drama|Thriller
# movieId is 679,title is Run of the Country, The (1995),genres is Drama
# movieId is 680,title is Alphaville (Alphaville, une étrange aventure de Lemmy Caution) (1965),genres is Drama|Mystery|Romance|Sci-Fi|Thriller
# movieId is 681,title is Coup de torchon (Clean Slate) (1981),genres is Crime
# movieId is 685,title is It's My Party (1996),genres is Drama
# movieId is 687,title is Country Life (1994),genres is Drama|Romance
# movieId is 688,title is Operation Dumbo Drop (1995),genres is Action|Adventure|Comedy|War
# movieId is 690,title is Promise, The (Versprechen, Das) (1995),genres is Drama|Romance
# movieId is 691,title is Mrs. Winterbourne (1996),genres is Comedy|Romance
# movieId is 692,title is Solo (1996),genres is Action|Sci-Fi|Thriller
# movieId is 694,title is Substitute, The (1996),genres is Action|Crime|Drama
# movieId is 695,title is True Crime (1996),genres is Mystery|Thriller
# movieId is 696,title is Butterfly Kiss (1995),genres is Drama|Thriller
# movieId is 697,title is Feeling Minnesota (1996),genres is Drama|Romance
# movieId is 698,title is Delta of Venus (1995),genres is Drama
# movieId is 700,title is Angus (1995),genres is Comedy
# movieId is 702,title is Faces (1968),genres is Drama
# movieId is 703,title is Boys (1996),genres is Drama
# movieId is 704,title is Quest, The (1996),genres is Action|Adventure
# movieId is 705,title is Cosi (1996),genres is Comedy
# movieId is 707,title is Mulholland Falls (1996),genres is Crime|Drama|Thriller
# movieId is 708,title is Truth About Cats & Dogs, The (1996),genres is Comedy|Romance
# movieId is 709,title is Oliver & Company (1988),genres is Adventure|Animation|Children|Comedy|Musical
# movieId is 710,title is Celtic Pride (1996),genres is Comedy
# movieId is 711,title is Flipper (1996),genres is Adventure|Children
# movieId is 714,title is Dead Man (1995),genres is Drama|Mystery|Western
# movieId is 715,title is Horseman on the Roof, The (Hussard sur le toit, Le) (1995),genres is Drama|Romance
# movieId is 718,title is Visitors, The (Visiteurs, Les) (1993),genres is Comedy|Fantasy|Sci-Fi
# movieId is 719,title is Multiplicity (1996),genres is Comedy
# movieId is 720,title is Wallace & Gromit: The Best of Aardman Animation (1996),genres is Adventure|Animation|Comedy
# movieId is 721,title is Halfmoon (Paul Bowles - Halbmond) (1995),genres is Drama
# movieId is 722,title is Haunted World of Edward D. Wood Jr., The (1996),genres is Documentary
# movieId is 724,title is Craft, The (1996),genres is Drama|Fantasy|Horror|Thriller
# movieId is 725,title is Great White Hype, The (1996),genres is Comedy
# movieId is 726,title is Last Dance (1996),genres is Drama
# movieId is 728,title is Cold Comfort Farm (1995),genres is Comedy
# movieId is 731,title is Heaven's Prisoners (1996),genres is Crime|Thriller
# movieId is 733,title is Rock, The (1996),genres is Action|Adventure|Thriller
# movieId is 735,title is Cemetery Man (Dellamorte Dellamore) (1994),genres is Horror
# movieId is 736,title is Twister (1996),genres is Action|Adventure|Romance|Thriller
# movieId is 737,title is Barb Wire (1996),genres is Action|Sci-Fi
# movieId is 741,title is Ghost in the Shell (Kôkaku kidôtai) (1995),genres is Animation|Sci-Fi
# movieId is 742,title is Thinner (1996),genres is Horror|Thriller
# movieId is 743,title is Spy Hard (1996),genres is Comedy
# movieId is 745,title is Wallace & Gromit: A Close Shave (1995),genres is Animation|Children|Comedy
# movieId is 746,title is Force of Evil (1948),genres is Film-Noir
# movieId is 747,title is Stupids, The (1996),genres is Comedy
# movieId is 748,title is Arrival, The (1996),genres is Action|Sci-Fi|Thriller
# movieId is 750,title is Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964),genres is Comedy|War
# movieId is 753,title is Month by the Lake, A (1995),genres is Comedy|Drama|Romance
# movieId is 754,title is Gold Diggers: The Secret of Bear Mountain (1995),genres is Adventure|Children
# movieId is 755,title is Kim (1950),genres is Children|Drama
# movieId is 756,title is Carmen Miranda: Bananas Is My Business (1994),genres is Documentary
# movieId is 757,title is Ashes of Time (Dung che sai duk) (1994),genres is Drama
# movieId is 759,title is Maya Lin: A Strong Clear Vision (1994),genres is Documentary
# movieId is 760,title is Stalingrad (1993),genres is Drama|War
# movieId is 761,title is Phantom, The (1996),genres is Action|Adventure
# movieId is 762,title is Striptease (1996),genres is Comedy|Crime
# movieId is 764,title is Heavy (1995),genres is Drama|Romance
# movieId is 765,title is Jack (1996),genres is Comedy|Drama
# ...
# movieId is 135137,title is Pixels (2015),genres is Action|Comedy|Sci-Fi
# movieId is 135264,title is Zenon: Girl of the 21st Century (1999),genres is Adventure|Children|Comedy
# movieId is 135266,title is Zenon: The Zequel (2001),genres is Adventure|Children|Comedy|Sci-Fi
# movieId is 135268,title is Zenon: Z3 (2004),genres is Adventure|Children|Comedy
# movieId is 135436,title is The Secret Life of Pets (2016),genres is Animation|Comedy
# movieId is 135508,title is A Deadly Adoption (2015),genres is Comedy|Thriller
# movieId is 135518,title is Self/less (2015),genres is Action|Mystery|Sci-Fi|Thriller
# movieId is 135532,title is The Last Witch Hunter (2015),genres is Action|Adventure|Fantasy
# movieId is 135536,title is Suicide Squad (2016),genres is Action|Crime|Sci-Fi
# movieId is 135567,title is Independence Day: Resurgence (2016),genres is Action|Adventure|Sci-Fi
# movieId is 135569,title is Star Trek 3 (2016),genres is Action|Adventure|Sci-Fi
# movieId is 135861,title is Ted 2 (2015),genres is Comedy
# movieId is 135887,title is Minions (2015),genres is Adventure|Animation|Children|Comedy
# movieId is 136016,title is The Good Dinosaur (2015),genres is Adventure|Animation|Children|Comedy|Fantasy
# movieId is 136018,title is Black Mass (2015),genres is Crime|Drama
# movieId is 136020,title is Spectre (2015),genres is Action|Adventure|Crime
# movieId is 136305,title is Sharknado 3: Oh Hell No! (2015),genres is Horror|Sci-Fi
# movieId is 136445,title is George Carlin: Back in Town (1996),genres is Comedy
# movieId is 136447,title is George Carlin: You Are All Diseased (1999),genres is Comedy
# movieId is 136449,title is Ghost in the Shell 2.0 (2008),genres is Action|Animation|Sci-Fi
# movieId is 136562,title is Steve Jobs (2015),genres is Drama
# movieId is 136592,title is Freaky Friday (1995),genres is (no genres listed)
# movieId is 136598,title is Vacation (2015),genres is Adventure|Comedy
# movieId is 136602,title is Creep (2014),genres is Horror|Thriller
# movieId is 136654,title is The Face of an Angel (2015),genres is Drama
# movieId is 136666,title is Search Party (2014),genres is Comedy
# movieId is 136800,title is Robot Overlords (2014),genres is Action|Adventure|Sci-Fi
# movieId is 136816,title is Bad Asses on the Bayou (2015),genres is Action|Comedy
# movieId is 136864,title is Batman v Superman: Dawn of Justice (2016),genres is Action|Adventure|Fantasy|Sci-Fi
# movieId is 137337,title is Amy (2015),genres is Documentary
# movieId is 137403,title is Swimming Upstream (2002),genres is Drama
# movieId is 137595,title is Magic Mike XXL (2015),genres is Comedy|Drama
# movieId is 137857,title is The Jungle Book (2016),genres is Adventure|Drama|Fantasy
# movieId is 138036,title is The Man from U.N.C.L.E. (2015),genres is Action|Adventure|Comedy
# movieId is 138204,title is 7 Days in Hell (2015),genres is Comedy
# movieId is 138208,title is The Walk (2015),genres is Adventure|Drama|Thriller
# movieId is 138258,title is Nasty Baby (2015),genres is Drama
# movieId is 138546,title is The Opposite Sex (2014),genres is Comedy
# movieId is 138610,title is The Gallows (2015),genres is Horror|Thriller
# movieId is 138696,title is Hands in the Air (2010),genres is Comedy|Drama|Romance
# movieId is 138698,title is El vals de los inútiles (2014),genres is Documentary
# movieId is 139116,title is Requiem For The Big East (2014),genres is Documentary
# movieId is 139130,title is Afro Samurai (2007),genres is Action|Adventure|Animation|Drama|Fantasy
# movieId is 139385,title is The Revenant (2015),genres is Adventure|Drama
# movieId is 139415,title is Irrational Man (2015),genres is Crime|Drama
# movieId is 139620,title is Everything's Gonna Be Great (1998),genres is Adventure|Children|Comedy|Drama
# movieId is 139642,title is Southpaw (2015),genres is Action|Drama
# movieId is 139644,title is Sicario (2015),genres is Crime|Drama|Mystery
# movieId is 139757,title is Best of Enemies (2015),genres is Documentary
# movieId is 139855,title is Anomalisa (2015),genres is Animation|Comedy|Fantasy
# movieId is 139915,title is How to Make Love Like an Englishman (2014),genres is Comedy|Romance
# movieId is 140110,title is The Intern (2015),genres is Comedy
# movieId is 140152,title is Dreamcatcher (2015),genres is Children|Crime|Documentary
# movieId is 140174,title is Room (2015),genres is Drama
# movieId is 140237,title is The Runner (2015),genres is Drama
# movieId is 140247,title is The Gift (2015),genres is Drama|Horror
# movieId is 140265,title is George Carlin: Jammin' in New York (1992),genres is Comedy
# movieId is 140267,title is The Witch (2015),genres is Horror
# movieId is 140523,title is Visit, The (2015),genres is Comedy|Horror
# movieId is 140711,title is American Ultra (2015),genres is Action|Comedy|Sci-Fi|Thriller
# movieId is 140715,title is Straight Outta Compton (2015),genres is Drama
# movieId is 140725,title is Cop Car (2015),genres is Crime|Thriller
# movieId is 140739,title is Eighteen (2005),genres is Drama
# movieId is 140741,title is Get Your Stuff (2000),genres is Drama|Romance
# movieId is 140743,title is The Man I Love (1997),genres is Drama
# movieId is 140745,title is 10 Attitudes (2001),genres is Comedy|Drama|Romance
# movieId is 140747,title is 16 Wishes (2010),genres is Children|Drama|Fantasy
# movieId is 140749,title is 29th and Gay (2005),genres is Comedy
# movieId is 140751,title is Almost Normal (2005),genres is Comedy|Drama|Sci-Fi
# movieId is 140753,title is The Men Next Door (2012),genres is (no genres listed)
# movieId is 140755,title is Long-Term Relationship (2006),genres is Comedy|Romance
# movieId is 140757,title is 3-Day Weekend (2008),genres is Drama
# movieId is 140759,title is The Big Gay Musical (2009),genres is Comedy|Drama|Romance
# movieId is 140761,title is The Biggest Fan (2002),genres is Comedy|Romance
# movieId is 140763,title is Boy Crazy (2009),genres is (no genres listed)
# movieId is 140816,title is Tangerine (2015),genres is Comedy|Drama
# movieId is 140880,title is Fashion Victims (2007),genres is Comedy
# movieId is 140928,title is Joy (2015),genres is Comedy|Drama
# movieId is 141124,title is FAQs (2005),genres is Drama
# movieId is 141422,title is Suffragette (2015),genres is Drama
# movieId is 141668,title is War Room (2015),genres is Drama
# movieId is 141688,title is Legend (2015),genres is Crime|Thriller
# movieId is 141718,title is Deathgasm (2015),genres is Comedy|Horror
# movieId is 141749,title is The Danish Girl (2015),genres is Drama
# movieId is 141866,title is Green Room (2015),genres is (no genres listed)
# movieId is 141886,title is The Dress (1996),genres is Comedy|Drama
# movieId is 141890,title is Beasts of No Nation (2015),genres is Drama|War
# movieId is 141956,title is Contracted: Phase II (2015),genres is Drama|Horror|Thriller
# movieId is 142068,title is Tiger Orange (2014),genres is Drama
# movieId is 142192,title is Female on the Beach (1955),genres is Crime|Drama|Mystery|Romance|Thriller
# movieId is 142240,title is Romeos (2011),genres is Drama
# movieId is 142258,title is Listen to Me Marlon (2015),genres is Documentary
# movieId is 142422,title is The Night Before (2015),genres is Comedy
# movieId is 142448,title is Everest (2015),genres is Adventure|Drama|Thriller
# movieId is 142488,title is Spotlight (2015),genres is Thriller
# movieId is 142507,title is Pawn Sacrifice (2015),genres is Drama
# movieId is 142536,title is Burnt (2015),genres is Drama
# movieId is 142997,title is Hotel Transylvania 2 (2015),genres is Animation|Comedy
# movieId is 143255,title is Narcopolis (2014),genres is Mystery|Sci-Fi|Thriller
# movieId is 143257,title is Ashby (2015),genres is Comedy|Drama
# movieId is 143377,title is Glen Campbell: I'll Be Me (2014),genres is Documentary|Drama
# movieId is 143385,title is Bridge of Spies (2015),genres is Drama|Thriller
# movieId is 143410,title is Hyena Road,genres is (no genres listed)
# movieId is 143472,title is Into the Grizzly Maze (2015),genres is Action|Horror|Thriller
# movieId is 143657,title is The Invitation (2015),genres is Horror|Thriller
# movieId is 143859,title is Hail, Caesar! (2016),genres is Comedy
# movieId is 144172,title is February (2015),genres is Horror
# movieId is 144620,title is Goosebumps (2015),genres is Adventure|Comedy|Horror
# movieId is 144714,title is The Perfect Guy (2015),genres is Drama|Thriller
# movieId is 144976,title is Bone Tomahawk (2015),genres is Horror|Western
# movieId is 145150,title is The Dressmaker (2015),genres is Comedy|Drama|Thriller
# movieId is 145307,title is Strictly Business (1991),genres is Comedy|Romance
# movieId is 145775,title is Rubble Kings (2015),genres is Documentary
# movieId is 145839,title is Concussion (2015),genres is Drama
# movieId is 145935,title is Peanuts Movie, The (2015),genres is Adventure|Animation|Children|Comedy
# movieId is 146309,title is The Boy and the Beast (2015),genres is Action|Adventure|Animation
# movieId is 146443,title is Plan B (2009),genres is Comedy|Drama|Romance
# movieId is 146501,title is Land of Storms (2014),genres is Drama
# movieId is 146604,title is Naomi and Ely's No Kiss List (2015),genres is Comedy|Drama|Romance
# movieId is 146656,title is Creed (2015),genres is Drama
# movieId is 146682,title is Twinsters (2015),genres is Documentary
# movieId is 146688,title is Solace (2015),genres is Fantasy|Mystery|Thriller
# movieId is 147006,title is Bana Masal Anlatma (2015),genres is Comedy|Drama
# movieId is 147010,title is Thou Gild'st the Even (2013),genres is Drama|Fantasy|Romance
# movieId is 147037,title is Straight-Jacket (2004),genres is Comedy
# movieId is 147426,title is İtirazım Var (2014),genres is Action|Crime|Drama
# movieId is 147845,title is Manson Family Vacation (2015),genres is Comedy|Drama|Thriller
# movieId is 148168,title is Pek Yakında (2014),genres is Action|Comedy|Drama
# movieId is 148238,title is A Very Murray Christmas (2015),genres is Comedy
# movieId is 148372,title is Schneider vs. Bax (2015),genres is Comedy|Thriller
# movieId is 148482,title is Truth (2015),genres is Drama
# movieId is 148626,title is Big Short, The (2015),genres is Drama
# movieId is 148652,title is The Ridiculous 6 (2015),genres is Comedy|Western
# movieId is 148881,title is World of Tomorrow (2015),genres is Animation|Comedy
# movieId is 148888,title is Zoolander 2 (2016),genres is Comedy
# movieId is 148956,title is How to Be Single (2016),genres is Comedy|Romance
# movieId is 149352,title is Daddy's Home (2015),genres is Comedy
# movieId is 149354,title is Sisters (2015),genres is Children|Comedy
# movieId is 149406,title is Kung Fu Panda 3 (2016),genres is Action|Adventure|Animation
# movieId is 149532,title is Marco Polo: One Hundred Eyes (2015),genres is (no genres listed)
# movieId is 149572,title is A.R.O.G. (2008),genres is Comedy|Fantasy
# movieId is 149590,title is Standoff (2016),genres is Thriller
# movieId is 149606,title is Bajirao Mastani (2015),genres is Romance|War
# movieId is 149612,title is Swelter (2014),genres is Action|Drama|Thriller
# movieId is 149830,title is Pride and Prejudice and Zombies (2016),genres is Comedy|Horror|Romance|Thriller
# movieId is 150401,title is Close Range (2015),genres is Action|Crime
# movieId is 150548,title is Sherlock: The Abominable Bride (2016),genres is Action|Crime|Drama|Mystery|Thriller
# movieId is 150856,title is Making a Murderer (2015),genres is Documentary
# movieId is 151307,title is The Lovers and the Despot,genres is (no genres listed)
# movieId is 151639,title is The Boy (2016),genres is Horror|Thriller
# movieId is 152017,title is Me Before You (2016),genres is Drama|Romance
# movieId is 152025,title is SOMM: Into the Bottle (2016),genres is Documentary
# movieId is 152057,title is Miles Ahead (2016),genres is Drama
# movieId is 152077,title is 10 Cloverfield Lane (2016),genres is Thriller
# movieId is 152079,title is London Has Fallen (2016),genres is Action|Crime|Thriller
# movieId is 152081,title is Zootopia (2016),genres is Action|Adventure|Animation|Children|Comedy
# movieId is 152091,title is The Brothers Grimsby (2016),genres is Comedy
# movieId is 152173,title is Michael Jackson's Thriller (1983),genres is Horror
# movieId is 152844,title is Demons (1971),genres is Horror
# movieId is 153584,title is The Last Days of Emma Blank (2009),genres is Comedy
# movieId is 155064,title is The Neon Demon (2016),genres is Drama|Horror|Mystery
# movieId is 155392,title is Hello, My Name Is Doris (2016),genres is Drama
# movieId is 155611,title is Life Is Sacred (2014),genres is Documentary
# movieId is 155820,title is Keanu (2016),genres is Comedy
# movieId is 156025,title is Ice Age: The Great Egg-Scapade (2016),genres is Adventure|Animation|Children|Comedy
# movieId is 156387,title is Sing Street (2016),genres is Drama
# movieId is 156607,title is The Huntsman Winter's War (2016),genres is Action|Adventure|Drama|Fantasy
# movieId is 156609,title is Neighbors 2: Sorority Rising (2016),genres is Comedy
# movieId is 156726,title is Hush (2016),genres is Thriller
# movieId is 157200,title is Money Monster (2016),genres is Drama|Thriller
# movieId is 157296,title is Finding Dory (2016),genres is Adventure|Animation|Comedy
# movieId is 157407,title is I Am Wrath (2016),genres is Action|Crime|Drama|Thriller
# movieId is 157667,title is Mother's Day (2016),genres is Comedy
# movieId is 158238,title is The Nice Guys (2016),genres is Crime|Mystery|Thriller
# movieId is 158314,title is Daniel Tosh: Completely Serious (2007),genres is Comedy
# movieId is 158528,title is The Shallows (2016),genres is Drama|Thriller
# movieId is 158783,title is The Handmaiden (2016),genres is Drama|Romance|Thriller
# movieId is 158956,title is Kill Command (2016),genres is Action|Horror|Sci-Fi
# movieId is 159093,title is Now You See Me 2 (2016),genres is Action|Comedy|Thriller
# movieId is 159462,title is The Video Dead (1987),genres is Horror
# movieId is 159690,title is Teenage Mutant Ninja Turtles: Out of the Shadows (2016),genres is Action|Adventure|Comedy
# movieId is 159755,title is Popstar: Never Stop Never Stopping (2016),genres is Comedy
# movieId is 159858,title is The Conjuring 2 (2016),genres is Horror
# movieId is 159972,title is Approaching the Unknown (2016),genres is Drama|Sci-Fi|Thriller
# movieId is 160080,title is Ghostbusters (2016),genres is Action|Comedy|Horror|Sci-Fi
# movieId is 160271,title is Central Intelligence (2016),genres is Action|Comedy
# movieId is 160438,title is Jason Bourne (2016),genres is Action
# movieId is 160440,title is The Maid's Room (2014),genres is Thriller
# movieId is 160563,title is The Legend of Tarzan (2016),genres is Action|Adventure
# movieId is 160565,title is The Purge: Election Year (2016),genres is Action|Horror|Sci-Fi
# movieId is 160567,title is Mike & Dave Need Wedding Dates (2016),genres is Comedy
# movieId is 160590,title is Survive and Advance (2013),genres is (no genres listed)
# movieId is 160656,title is Tallulah (2016),genres is Drama
# movieId is 160718,title is Piper (2016),genres is Animation
# movieId is 160954,title is Nerve (2016),genres is Drama|Thriller
# movieId is 161084,title is My Friend Rockefeller (2015),genres is Documentary
# movieId is 161155,title is Sunspring (2016),genres is Sci-Fi
# movieId is 161336,title is Author: The JT LeRoy Story (2016),genres is Documentary
# movieId is 161582,title is Hell or High Water (2016),genres is Crime|Drama
# movieId is 161594,title is Kingsglaive: Final Fantasy XV (2016),genres is Action|Adventure|Animation|Drama|Fantasy|Sci-Fi
# movieId is 161830,title is Body (2015),genres is Drama|Horror|Thriller
# movieId is 161918,title is Sharknado 4: The 4th Awakens (2016),genres is Action|Adventure|Horror|Sci-Fi
# movieId is 161944,title is The Last Brickmaker in America (2001),genres is Drama
# movieId is 162376,title is Stranger Things,genres is Drama
# movieId is 162542,title is Rustom (2016),genres is Romance|Thriller
# movieId is 162672,title is Mohenjo Daro (2016),genres is Adventure|Drama|Romance
# movieId is 163056,title is Shin Godzilla (2016),genres is Action|Adventure|Fantasy|Sci-Fi
# movieId is 163949,title is The Beatles: Eight Days a Week - The Touring Years (2016),genres is Documentary
# movieId is 164977,title is The Gay Desperado (1936),genres is Comedy
# movieId is 164979,title is Women of '69, Unboxed,genres is Documentary

# %%
type(rdd_movies)
# Out:
# list

# %%
df_movies.printSchema()
# Out:
# root
#  |-- movieId: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- genres: string (nullable = true)

# %%
# 这两句连接mysql的语句是写错了的。在没有调用load函数的时候，语句运行正常。但是加上load函数之后，就直接报错。java.sql.SQLException: No suitable driver

# dt = spark.read.format("jdbc").options(url="jdbc:mysql://localhost:3306/mydb?user=root&password=123456",dbtable="userphone").load()

# dataframe_mysql=spark.read.format("jdbc").option("url", "jdbc:mysql://localhost:3306/mydb").option("dbtable", "userphone").option("user", "root").option("password", "123456").load()

# %%
dt = spark.read.format("jdbc").options(url="jdbc:mysql://localhost:3306/mydb",driver="com.mysql.jdbc.Driver",dbtable="userphone",user="root",password="123456")

# %%
jdbcDF = dt.load()

# %%
jdbcDF.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- phone: string (nullable = true)
#  |-- trueName: string (nullable = true)

# %%
jdbcDF.show()
# Out:
# +---+-----------+--------+
# | id|      phone|trueName|
# +---+-----------+--------+
# |  1|15733218050|    lili|
# |  2|15778423030|    lisa|
# |  3|18620192711|     tom|
# |  4|15733218050|    john|
# +---+-----------+--------+
